# %% [markdown]
# # 调试功能

# %%
from bert4nlp.dataset.ner_dataset import get_ner_loader

# %%
loader = get_ner_loader('./rsrc/JD_NER/', dataset='jd',max_seq_len=128,batch_size=8,split='test')

# %%
loader.dataset.tz.label2idx
# Out:
# {'O': 0,
#  'B-1': 1,
#  'B-10': 2,
#  'B-11': 3,
#  'B-12': 4,
#  'B-13': 5,
#  'B-14': 6,
#  'B-15': 7,
#  'B-16': 8,
#  'B-17': 9,
#  'B-18': 10,
#  'B-19': 11,
#  'B-2': 12,
#  'B-20': 13,
#  'B-21': 14,
#  'B-22': 15,
#  'B-23': 16,
#  'B-24': 17,
#  'B-25': 18,
#  'B-26': 19,
#  'B-28': 20,
#  'B-29': 21,
#  'B-3': 22,
#  'B-30': 23,
#  'B-31': 24,
#  'B-32': 25,
#  'B-33': 26,
#  'B-34': 27,
#  'B-35': 28,
#  'B-36': 29,
#  'B-37': 30,
#  'B-38': 31,
#  'B-39': 32,
#  'B-4': 33,
#  'B-40': 34,
#  'B-41': 35,
#  'B-42': 36,
#  'B-43': 37,
#  'B-44': 38,
#  'B-46': 39,
#  'B-47': 40,
#  'B-48': 41,
#  'B-49': 42,
#  'B-5': 43,
#  'B-50': 44,
#  'B-51': 45,
#  'B-52': 46,
#  'B-53': 47,
#  'B-54': 48,
#  'B-6': 49,
#  'B-7': 50,
#  'B-8': 51,
#  'B-9': 52,
#  'I-1': 53,
#  'I-10': 54,
#  'I-11': 55,
#  'I-12': 56,
#  'I-13': 57,
#  'I-14': 58,
#  'I-15': 59,
#  'I-16': 60,
#  'I-17': 61,
#  'I-18': 62,
#  'I-19': 63,
#  'I-2': 64,
#  'I-20': 65,
#  'I-21': 66,
#  'I-22': 67,
# ...

# %%
loader.dataset.tz.idx2label
# Out:
# {0: 'O',
#  1: 'B-1',
#  2: 'B-10',
#  3: 'B-11',
#  4: 'B-12',
#  5: 'B-13',
#  6: 'B-14',
#  7: 'B-15',
#  8: 'B-16',
#  9: 'B-17',
#  10: 'B-18',
#  11: 'B-19',
#  12: 'B-2',
#  13: 'B-20',
#  14: 'B-21',
#  15: 'B-22',
#  16: 'B-23',
#  17: 'B-24',
#  18: 'B-25',
#  19: 'B-26',
#  20: 'B-28',
#  21: 'B-29',
#  22: 'B-3',
#  23: 'B-30',
#  24: 'B-31',
#  25: 'B-32',
#  26: 'B-33',
#  27: 'B-34',
#  28: 'B-35',
#  29: 'B-36',
#  30: 'B-37',
#  31: 'B-38',
#  32: 'B-39',
#  33: 'B-4',
#  34: 'B-40',
#  35: 'B-41',
#  36: 'B-42',
#  37: 'B-43',
#  38: 'B-44',
#  39: 'B-46',
#  40: 'B-47',
#  41: 'B-48',
#  42: 'B-49',
#  43: 'B-5',
#  44: 'B-50',
#  45: 'B-51',
#  46: 'B-52',
#  47: 'B-53',
#  48: 'B-54',
#  49: 'B-6',
#  50: 'B-7',
#  51: 'B-8',
#  52: 'B-9',
#  53: 'I-1',
#  54: 'I-10',
#  55: 'I-11',
#  56: 'I-12',
#  57: 'I-13',
#  58: 'I-14',
#  59: 'I-15',
#  60: 'I-16',
#  61: 'I-17',
#  62: 'I-18',
#  63: 'I-19',
#  64: 'I-2',
#  65: 'I-20',
#  66: 'I-21',
#  67: 'I-22',
# ...
